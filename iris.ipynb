# %% [markdown]
# <a href="https://colab.research.google.com/github/natka67/learning_python/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
x = iris.data
y = iris.target

feature_names=iris.feature_names
target_names = iris.target_names
type(x)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.40)

print(x_train.shape)
print(x_test.shape)
# Out:
# (90, 4)
# (60, 4)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
yk_pred = knn.predict(x_test)

# %%
tnn = DecisionTreeClassifier()
tnn.fit(x_train, y_train)
yt_pred = knn.predict(x_test)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test, yk_pred)
# Out:
# 0.9666666666666667

# %%
metrics.accuracy_score(y_test, yt_pred)
# Out:
# 0.9666666666666667
